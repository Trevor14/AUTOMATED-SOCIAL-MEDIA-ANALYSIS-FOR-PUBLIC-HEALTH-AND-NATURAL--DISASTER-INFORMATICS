# %% [markdown]
# <h1 align="center">Term Paper</h1>
# <h2 align="center">AUTOMATED SOCIAL MEDIA ANALYSIS FOR PUBLIC HEALTH AND NATURAL DISASTER INFORMATICS AND RESPONSE</h2>

# %% [markdown]
# ![CUT](http://news.pindula.co.zw/wp-content/uploads/2016/10/Chinhoyi-University-of-Technology-logo.png)

# %% [markdown]
# **Submitted by:** Trevor Machimbidza (C15124744X)<br>
# **Programme   :** MSc Data Analytics <br>
# **Course      :** MSCDA601 Fundamentals of Programming <br>
# **Lecturer      :** T.D.Kavu <br>
# **Submission  :** 21 April 2020

# %% [markdown]
# ## 1. Abstract

# %% [markdown]
# Social media tools are integrated in most parts of our daily lives, as citizens, netizens, researchers or emergency responders. Lessons learnt from disasters and emergencies that occurred globally in the last few years have shown that social media tools may serve as an integral and significant component of crisis response. Communication is one of the fundamental tools of emergency management. It becomes crucial when there are dozens of agencies and organizations responding to a disaster. Regardless of the type of emergency, whether a terrorist attack, a hurricane or an earthquake, communication lines may be overloaded and cellular networks overwhelmed as too many people attempt to use them to access information. Social scientists have presented that post-disaster active public participation was largely altruistic, including activities such as search and rescue, first aid treatment, victim evacuation, and on-line help. Social media provides opportunities for engaging citizens in the emergency management by both disseminating information to the public and accessing information from them. During emergency events, individuals are exposed to large quantities of information without being aware of their validity or risk of misinformation, but users are usually swift to correct them, thus making the social media “self-regulating”. Appreciation of the positive side of social media is balanced by their potential for negative developments, such as disseminating rumours and undermining authority. This leads to an examination of the ethics of social media usage in crisis situations. Despite some clearly identiﬁable risks, for example regarding the violation of privacy, it appears that public consensus on ethics will tend to override unscrupulous attempts to subvert the media. Moreover, social media are a robust means of exposing corruption and malpractice. In synthesis, the widespread adoption and use of social media by members of the public throughout the world heralds a new age in which it is imperative that emergency managers adapt their working practices to the challenge and potential of this development. At the same time, they must heed the ethical warnings and ensure that social media is not abused or misused when crises and emergencies occur.

# %% [markdown]
# ### KEYWORDS: Sentiment Analysis, Coronavirus, Covid-19,Twitter, Python Programming

# %% [markdown]
# ## 2. Problem statement

# %% [markdown]
# During this current ongoing outbreak of coronavirus disease (COVID-19), people using social media to acquire and exchange various types of information at a historic and unprecedented scale.Today, social media platforms such as Twitter, have become primary sources of information. They are also vehicles for fake news and disinformation which can raise public fear and stress levels. From the perspective of social media users, whether users have a higher number of followers or followees (proxies of the social capital) and whether they are verified users or not also positively affect the propagation scale of the post in various social media platforms. Another user related feature is users’ location, and if users are from the developed cities, they are more likely to attract more social capital which will enlarge their influence upon others. In addition, in this case of (COVID -19 ) public health disaster, people are more likely to share the posts from users who are eyewitnesses of the event and geographically located near the event . Besides, affiliations and perceptions of people could also affect users’ information sharing behavior. During a crisis like the COVID-19 pandemic,only the situational information is valuable and available mostly to the public and authorities to respond to the epidemic. Different researchers categorized situational information into different types. For example, Rudra et al. defined situational information as those notifications of the casualties or injured/stranded people or helping relief operations and categorized sympathizing with the victims, praising or criticizing the relief operation, post analysis of the reasons the crisis happens, and donation related information into non situational information. Therefore, it is important to identify such situational information and to understand how it is being propagated on social media, so that appropriate information publishing strategies can be informed for the COVID-19 epidemic. This article sought to fill this gap by harnessing data and natural language processing techniques to classify the COVID-19-related information. The results provide data driven insights into the information needed and public attention.

# %% [markdown]
# ## 3. Aims and Objectives

# %% [markdown]
# ### 3.1 Aims

# %% [markdown]
# Against this background, the aim of this research is to analyse the sentiments of the general public on social media analysis on public health informatics and response on the on going pandemic of covid-19.

# %% [markdown]
# ### 3.2 Objectives
# * To collect data on the sentiments, emotions and opinions expressed by the general public on social media in regard to the covid-19.
# * To conduct a sentiment analysis of the social media responses and informatics of the public health crisis.
# * To identify the most liked/ retweeted tweets on covid-19

# %% [markdown]
# ## 4. Related Works

# %% [markdown]
# Sentiment analysis has stimulated the interest of many researchers and a lot of work has been done with regards to sentiment analysis especially with regards to the review of user views on web blogs and articles or documents. These are, however, different from twitter mainly due to the limit of 140 characters per tweet which enforces opinion compression of text. The best results reached in sentiment classification use supervised learning techniques such as Naive Bayes and Support Vector Machines. Studies on sentiment analysis have mainly put emphasis on context, lexicon based approach and machine learning approach.The machine learning approach involves feature extraction  which is divided into the training and test set, where the training set is the learning set and Test set is used to check how the training test performs in classification. The bag-of-words model is  simple and the most commonly used lexicon based aproach, it has been used by many researchers in sentiment analysis, the model represents the text to be classified as collection of words, which will be classified into positive, negative or neutral polarity. The overall polarity of texts is calculated by summing the individual polarity of words that make the text.
#
# In times of national and global emergencies, social media has a more important role than ever to play.In this instance during this COVID-19 pandemic majority of the countries world wide issued out lockdowns,leaving social media as the only source of information and news.The Pew Research Center in the US reports in 2020 over half of adults world wide turned to social media for their news and updates (Gao et al. 2011b). In a crisis, information is only helpful if it's relevant and accurate (Plotnick et al. 2009).This may range from crucial announcements on changes to operations, updates on specific company initiatives dedicated to individuals or communities affected by Covid-19 or any concessions made to better accommodate the customer's situation. Not much has been done to track the response of people during this pandemic since its currently on going,however somefew organisations have started research already. A study done so far by social media monitoring brandwatch, as analysed posts from platforms around the world on the topic of Covid-19 and, not surprisingly, has found them overwhelmingly negative. In particular, it reports of the phrase ‘out of stock’ having gone as panic buying has been reported in supermarkets worldwide.The number of press articles mentioning coronavirus stockpiling or hoarding was lower than organic social mentions. At the peak of toilet paper stockpiling in early March, a peak in news mentions of stockpiling came just before a spike in social mentions of the practice.This reaserch by brandwatch proves that much of the panick by people evolves from social media and by trying by all means to create and elliminate the fake news to restore calm in people.
# In Zimbabwe currently the measure to categorise spreading of fake news about the pandemic is at Level 14 offence which is part of Government’s efforts to ensure that the country effectively contains the spread of Covid-19. This is part of a Statutory Instrument (SI) under the Public Health Act, which now criminalises the peddling of falsehoods relating to this pandemic.The reason we had to come up with that SI was after we noted the proliferation of fake news, which were hindering the fight against the spread of the pandemic. We are using the Public Health Act which according to Section 68, empowers the Minister of Health and Child Care to make such regulations in times of emergencies, to help contain such viruses,” it was vital for people to realise the effect of spreading falsehoods on the functions of society as it had the danger of causing unnecessary panic and even affect Government efforts to contain emergencies “No society can function when lies are peddled willy-nilly, these could have a far reaching ripple effect that could even affect the nation more than the effects of the pandemic alone, hence the reason Government has decided to criminalise this practice especially on various social media platforms,”. said Minister Ziyambi.

# %% [markdown]
# ## 5. Methodology(approach)

# %% [markdown]
# Methodology involves the different stages and procedures used in the retrieval and analysis of data.

# %% [markdown]
# #### 5.1 Data Collection

# %% [markdown]
# The data set used in this research contain tweets collected from Twitter between 1 August 2018, when the new Minister of Finance took office, and 28 August 2019. The "twint" libray in and python environment was used to retrieve and download tweets with the keyword word "covid-19", to obtain  tweets associated with covid19 of Zimbabwe. The twint library allows developers to search for tweets containing a specific phrase or a specific word or associated with a specific user. The keyword used to search for tweets related to covid19 in Zimbabwe.

# %% [markdown]
# The "Tweepy" Python library is an alternative library to "twint" and is an approved twitter search API to collect data through the python environment. However, this library has some major drawback with the biggest being the limit placed on the historical period for which one can extract tweets i.e. 7 days, making it unsuitable for our research. Consequently, the "twint" library was used in preference to the "tweepy" library.

# %% [markdown]
# #### 5.2 Data Cleaning

# %% [markdown]
# Data cleaning involved a number of steps to ensure the data used is of a good quality with no missing information/ fields.
# * 5.2.1: Data upload - uploading the data collected from "twint" in to the python environment.
# * 5.2.2: Conversion of date fields uploaded as strings objects to a date time object.
# * 5.2.3: Selection of key field for analysis.
# * 5.2.4: Checking for missing values and imputing the missing values where neccessary.
#
#
#
#
# the  data cleaning which is one of the important aspects of data mining process,Cleaning of Twitter data is necessary as it eliminates  twitter  features that  are not useful for analysis. The  processed data obtained from  data preprocessing  is  in terms of words or phrases  that can simply  classify the class. Python code has been created  to obtain processed tweet.

# %% [markdown]
# #### 5.3 Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analsysis is the first step of data analysis and allowed us to:
# * 5.3.1: Visualize distributions and relationships
# * 5.3.2: Detect and clean errors or unwanted data
# * 5.3.3: Assess the suitable of the available data for the intended use case.
# * 5.3.4: Remove stop words which do not add any value to the analysis

# %% [markdown]
# ####  5.4 TextBlob Text Classification/ Sentiment Analysis

# %% [markdown]
# TextBlob is a python library and offers a simple API to access its methods and perform basic Natural Lunguage Processing (NLP) tasks. The TextBlob library's inbuilt sentiment function which was used to classify words into positive, negative and neutral polarity.
# Polarity is returned as float number which lies in the range of [-1,1] where 1 represents a positive sentiment, 0 represents a neutral sentiment and -1 represents a negative sentiment.

# %% [markdown]
# #### 5.5 Evaluation

# %% [markdown]
# Once the data has been adequately cleaned and each tweet has been classified using the texblob text blob sentiment analysis tool for polarity, the results are evaluated and visualised in preparation for detailed analysis. A number of aides are used to evaluate and visualise the resultant data, these inslude wordclouds, histograms and pie charts.

# %% [markdown]
# ## 6 Design of experiment

# %% [markdown]
# #### 6.1 Data Collection

# %% [markdown]
# The  code  below was used to extract tweets  in the anaconda  environment <br>
#
# twint -s "covid19" -o covid.csv  --csv

# %% [markdown]
# #### 6.2 Data Cleaning
# This sections contains the code and results for data upload and cleaning.

# %%
from textblob import TextBlob 
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np 
import pandas as pd
import re
from wordcloud import WordCloud
from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import sys

# %%
tweets = pd.read_csv('covid.csv', index_col='date',parse_dates=True)

# %%
df=tweets[['id','username','name','tweet','retweets_count','likes_count']]

# %% [markdown]
# #### 6.3 Exploratory Data Analysis

# %%
df.head()
# Out:
#                              id       username                  name  \
# date
# 2020-04-18  1251630014388264960   sibandasibbs       Thabisa Sibanda
# 2020-04-18  1251628555492098061  gilsonmandigo        Gilson Mandigo
# 2020-04-18  1251626808581206019      taf_joyce          tj chidzomba
# 2020-04-18  1251626098334498817       mohcczim  Ministry of HealthZW
# 2020-04-18  1251624048959913985   zadhrdoctors  ZADHR_DrsHumanRights
#
#                                                         tweet  retweets_count  \
# date
# 2020-04-18  Yes. Checking temperature and asking about Cov...               0
# 2020-04-18  This is actually the malaria season.. @bessing...               0
# 2020-04-18                       Are these not covid 19 cases               0
# 2020-04-18  COVID-19 Update: As at 18 April Zimbabwe had 2...              19
# 2020-04-18  #Covid19Zim Ministry of Health daily update. 1...               1
#
#             likes_count
# date
# 2020-04-18            0
# ...

# %%
df.tail()
# Out:
#                              id     username                 name  \
# date
# 2020-03-21  1241365952828256258     manmah28            Meginhard
# 2020-03-21  1241365732564316160   judasmkupe          judas mkupe
# 2020-03-21  1241365517258174464     tandjonh  Chamisa Chete Chete
# 2020-03-21  1241364927786483713   mulakazuva           Mulakazuva
# 2020-03-21  1241364869615620096  gamubrandon      Trouble Maker..
#
#                                                         tweet  retweets_count  \
# date
# 2020-03-21  Vane kahunu kekuita premature e.. Same same ne...               1
# 2020-03-21  Im not. Just be mature and  be baba  vekuti va...               0
# 2020-03-21  What do you mean by "foreign disease?" Is HIV ...               0
# 2020-03-21                                   Thank you Dokota               0
# 2020-03-21                                Which counterparts🤔               0
#
#             likes_count
# date
# 2020-03-21            2
# 2020-03-21            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3620 entries, 2020-04-18 to 2020-03-21
# Data columns (total 6 columns):
# id                3620 non-null int64
# username          3620 non-null object
# name              3620 non-null object
# tweet             3620 non-null object
# retweets_count    3620 non-null int64
# likes_count       3620 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 198.0+ KB

# %%
len(df)
# Out:
# 3620

# %%
df.shape
# Out:
# (3620, 6)

# %%
df.tweet
# Out:
# date
# 2020-04-18    Yes. Checking temperature and asking about Cov...
# 2020-04-18    This is actually the malaria season.. @bessing...
# 2020-04-18                         Are these not covid 19 cases
# 2020-04-18    COVID-19 Update: As at 18 April Zimbabwe had 2...
# 2020-04-18    #Covid19Zim Ministry of Health daily update. 1...
#                                     ...
# 2020-03-21    Vane kahunu kekuita premature e.. Same same ne...
# 2020-03-21    Im not. Just be mature and  be baba  vekuti va...
# 2020-03-21    What do you mean by "foreign disease?" Is HIV ...
# 2020-03-21                                     Thank you Dokota
# 2020-03-21                                  Which counterparts🤔
# Name: tweet, Length: 3620, dtype: object

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FD244BEBE0>,
# ...
#       dtype=object)

# %% [markdown]
# **Defining Key Functions and Classes**

# %%
def word_cloud(tweets):
    x, y = np.ogrid[:300, :300]
    mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
    mask = 255 * mask.astype(int)
    #We generate the wordcloud using the series created and the mask 
    word_cloud = WordCloud(width=4000, height=2000, max_font_size=200, 
                           background_color="white", max_words=2000, mask=mask, 
                           contour_width=1, contour_color="white", 
                           colormap="twilight_shifted").generate(tweets)

    #Now we plot the figure
    plt.figure(figsize=(15,15))
    plt.imshow(word_cloud, interpolation="bilinear")
    plt.axis("off")    
    plt.show()

# %%
def word_cloud2(text):
    #We get the directory that we are working on
    x, y = np.ogrid[:300, :300]
    mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
    mask = 255 * mask.astype(int)
   
    #We generate the wordcloud using the series created and the mask 
    word_cloud = WordCloud(width=2000, height=1000, max_font_size=200, 
                           background_color="white", max_words=2000, mask=mask, 
                           contour_width=1, contour_color="white", 
                           colormap="twilight_shifted").generate(text)

    #Now we plot the figure
    plt.figure(figsize=(15,15))
    plt.imshow(word_cloud, interpolation="bilinear")
    plt.axis("off")    
    plt.show()

# %%
def graph(word_frequency, sent):
    labels = word_frequency[0][0:50].index
    title = "Word Frequency for %s" %sent
    #Plot the figures
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(50), word_frequency[0][0:50], width = 0.8, color = sns.color_palette("bwr"), alpha=0.5, 
            edgecolor = "black", capsize=8, linewidth=1);
    plt.xticks(np.arange(50), labels, rotation=90, size=14);
    plt.xlabel("50 most frequent words", size=14);
    plt.ylabel("Frequency", size=14);
    #plt.title('Word Frequency for %s', size=18) %sent;
    plt.title(title, size=18)
    plt.grid(False);
    plt.gca().spines["top"].set_visible(False);
    plt.gca().spines["right"].set_visible(False);
    plt.show()

# %%
def graph2(word_frequency, sent):
    labels = word_frequency[0][0:50].index
    title = "Word Frequency for %s" %sent
    #Plot the figures
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(50), word_frequency[0][0:50], width = 0.8, color = sns.color_palette("bwr"), alpha=0.5, 
            edgecolor = "black", capsize=8, linewidth=1);
    plt.xticks(np.arange(50), labels, rotation=90, size=14);
    plt.xlabel("50 most frequent words", size=14);
    plt.ylabel("Frequency", size=14);
    #plt.title('Word Frequency for %s', size=18) %sent;
    plt.title(title, size=18)
    plt.grid(False);
    plt.gca().spines["top"].set_visible(False);
    plt.gca().spines["right"].set_visible(False);
    plt.show()

# %%
#Vectorization for Data Visualization
def vectorization(data):
    #CountVectorizer will convert a collection of text documents to a matrix of token counts
    #Produces a sparse representation of the counts 
    #Initialize
    vector = CountVectorizer()
    #We fit and transform the vector created
    frequency_matrix = vector.fit_transform(data['tweet'])
    #Sum all the frequencies for each word
    sum_frequencies = np.sum(frequency_matrix, axis=0)
    #Now we use squeeze to remove single-dimensional entries from the shape of an array that we got from applying np.asarray to
    #the sum of frequencies.
    frequency = np.squeeze(np.asarray(sum_frequencies))
    #Now we get into a dataframe all the frequencies and the words that they correspond to
    frequency_df = pd.DataFrame([frequency], columns=vector.get_feature_names()).transpose()
    return frequency_df

# %%
#Vectorization for Data Visualization
def vectorization2(data):
    #CountVectorizer will convert a collection of text documents to a matrix of token counts
    #Produces a sparse representation of the counts 
    #Initialize
    vector = CountVectorizer()
    #We fit and transform the vector created
    frequency_matrix = vector.fit_transform(data.text)
    #Sum all the frequencies for each word
    sum_frequencies = np.sum(frequency_matrix, axis=0)
    #Now we use squeeze to remove single-dimensional entries from the shape of an array that we got from applying np.asarray to
    #the sum of frequencies.
    frequency = np.squeeze(np.asarray(sum_frequencies))
    #Now we get into a dataframe all the frequencies and the words that they correspond to
    frequency_df = pd.DataFrame([frequency], columns=vector.get_feature_names()).transpose()
    return frequency_df

# %%
class TweetAnalyzer():
    """
    Functionality for analyzing and categorizing content from tweets.
    """

    def clean_tweet(self, tweet):
        return ' '.join(re.
                        sub("(pic.twitter.com/[A-Za-z0-9]+)|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)",
                            " ", tweet).split())

    def remove_stop_words(self,tweet):
        stop = stopwords.words('english')
        return ' '.join([word for word in tweet.split() if word not in (stop)])
    
    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 'Positive'
        elif analysis.sentiment.polarity == 0:
            return 'Neutral'
        else:
            return 'Negative'

# %% [markdown]
# **Convert all of the tweets into lower case.**

# %%
df['tweet'] = df['tweet'].apply(lambda x: x.lower())
# Out:
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Use regex to clean tweets:** <br>
# i)   remove all picture tags (i.e. remove every phrase that starts with pic.twitter.com) <br>
# ii)  remove the username/ twitter handle in every tweet (i.e. remove every word that starts with @) <br>
# iii) remove the hashtag in every tweet (i.e. remove every word that starts with #) <br>
# iv)  remove links to other websites in every tweet (i.e. remove every phrase that starts with "http")

# %%
tweet_analyzer = TweetAnalyzer()

df['tweet'] = np.array([tweet_analyzer.clean_tweet(tweet) for tweet in df['tweet']])
# Out:
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **Remove non value adding English stop words fom each tweet.**

# %%
df['tweet'] = np.array([tweet_analyzer.remove_stop_words(tweet) for tweet in df['tweet']])
# Out:
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Use TextBlob to carryout sentiment analysis of each tweet.**

# %%
df['sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweet']])
# Out:
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(2)
# Out:
#                              id       username             name  \
# date
# 2020-04-18  1251630014388264960   sibandasibbs  Thabisa Sibanda
# 2020-04-18  1251628555492098061  gilsonmandigo   Gilson Mandigo
#
#                                                         tweet  retweets_count  \
# date
# 2020-04-18  yes checking temperature asking covid 19 tests...               0
# 2020-04-18  actually malaria season right say diseases sym...               0
#
#             likes_count sentiment
# date
# 2020-04-18            0   Neutral
# 2020-04-18            1  Negative

# %% [markdown]
# ## 7. Results

# %% [markdown]
# **Draw a word cloud of all the tweets to identify the most mentioned words**

# %%
tweets = pd.Series([t for t in df.tweet]).str.cat(sep=' ')
word_cloud1 = word_cloud(tweets) 
word_cloud1

# %% [markdown]
# An analysis off the word cloud above suggests that the word "covid19" is the most mentioned word. The study is interested in finding out what the Users are saying about the covid 19.

# %%
exclusions=['think', 'public', 'many', 'still','must',
            'may','us','let',"via",'said','go','take','going','know','may']

# %%
df['tweet'] = df['tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (exclusions)]))

# %%
word_cloud_clean = word_cloud(pd.Series([t for t in df.tweet]).str.cat(sep=' ')) 
word_cloud_clean

# %%
word_frequency = vectorization(df).sort_values(0, ascending = False)
graph(word_frequency,'All')

# %% [markdown]
# The word cloud and frequency above shows that the most popular words used in most tweets include covid, zimbabwe, people,cases, testing etc.

# %% [markdown]
# ## 8. Analysis and Discussion

# %%
# Time Series
time_likes = pd.Series(data=df['sentiment'].resample('D', how='count'))
time_likes.plot(figsize=(20, 10), color='red', title = 'Analysis of Total Number of Tweets per Day')
plt.show()
# Out:
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()

# %% [markdown]
# The graph above shows a daily count of tweets on covid 19 in Zimbabwe. The trend shows that there was a spike in tweets in early April during the period in which the lockdown was effected.

# %%
print(df[['id','sentiment']].groupby('sentiment').count())
labels =('Negative', 'Neutral','Positive' )
data = df[['id','sentiment']].groupby('sentiment').count()
explode = (0.05, 0.05, 0.05)  # only "explode" the 2nd slice (i.e. 'Hogs')

plt.pie(data, explode=explode, labels=labels, autopct='%1.0f%%', radius= 2,
        shadow=True, startangle=90)
plt.title("Analysis of Sentiment")
plt.show()
# Out:
#              id
# sentiment
# Negative    681
# Neutral    1360
# Positive   1579
# C:\Users\emachimbidza\AppData\Local\Continuum\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   import sys

# %% [markdown]
# The pie chart above summarises the sentiments by sentiment polarity (i.e. positve, negative or neutral). Of the 10,578 tweets analysed 19% (2,021) had a negative sentiment, 38% (3,945) had a positive sentiment and 44% (4,612) had a neutral sentiment.

# %%
df[['name','tweet','retweets_count','sentiment']].\
                        sort_values(by = 'retweets_count',axis = 0, ascending = False).head(5)
# Out:
#                             name  \
# date
# 2020-03-23       ZBC News Online
# 2020-03-29            Third Axis
# 2020-03-27    Prof Jonathan Moyo
# 2020-03-25     Alex T Magaisa 🇿🇼
# 2020-03-22  Ministry of HealthZW
#
#                                                         tweet  retweets_count  \
# date
# 2020-03-23  minister health child care dr obediah moyo con...             391
# 2020-03-29  light urgent demand ppe zimbabwe curb spread c...             208
# 2020-03-27  coronavirusalert information affected families...             163
# 2020-03-25  thank jack medical equipment donated africa kl...             150
# 2020-03-22  tollfree hotline numbers suspect covid 19 dise...             130
#
#            sentiment
# date
# 2020-03-23  Positive
# 2020-03-29  Positive
# 2020-03-27   Neutral
# 2020-03-25   Neutral
# 2020-03-22   Neutral

# %% [markdown]
# The analysis above shows the top 5 most retweeted tweets. Out of the 5 tweets 3 are of a neutral sentiment which suggests that the general sentiment of users towards covid 19 was negative.

# %%
df[['name','tweet','likes_count','sentiment']].\
                        sort_values(by = 'likes_count',axis = 0, ascending = False).head(5)
# Out:
#                             name  \
# date
# 2020-03-27  Ministry of HealthZW
# 2020-03-23       ZBC News Online
# 2020-03-27    Prof Jonathan Moyo
# 2020-03-29            Third Axis
# 2020-03-25     Alex T Magaisa 🇿🇼
#
#                                                         tweet  likes_count  \
# date
# 2020-03-27  uz 2nd year master health student farai chiron...          856
# 2020-03-23  minister health child care dr obediah moyo con...          719
# 2020-03-27  coronavirusalert information affected families...          629
# 2020-03-29  light urgent demand ppe zimbabwe curb spread c...          598
# 2020-03-25  thank jack medical equipment donated africa kl...          598
#
#            sentiment
# date
# 2020-03-27   Neutral
# 2020-03-23  Positive
# 2020-03-27   Neutral
# 2020-03-29  Positive
# 2020-03-25   Neutral

# %% [markdown]
# The analysis above shows the top 5 most liked tweets. Out of the 5 tweets 3 are of a neutral sentiment which suggests that the general sentiment of users towards covid 19 was negative or neutral. A look at the neutral sentiments also suggests that these sentiments classified as neutral may have been wrongly classified when in fact they should have been classified as negative.

# %% [markdown]
# Overal the tables above suggest that the most liked and retweeded sentiments were of a negative nature. The top influencers with regards to covid 19 were by the "Ministry of healthZW" which had the most likes (856) and ZBC online the most retweets (391).

# %% [markdown]
# ## 9 Conclusion

# %% [markdown]
# Overall, the analysis suggests that most (i.e. 44%) Tweeter users who commented on the issue of covid 19 in Zimbabwean expressed a neutral sentiment and 38% had a positive sentiment and only 19% expressed a negative sentiment. However, further analysis of the findings suggests otherwise as the most retweeted and most liked tweets were of a negative sentiment. In addition, a significant number of the tweets were in shona and ndebele and would thus have been misclassified as neutral as they are not supported by the textblob sentiment analysis library. If time had permitted, there is need to have developed a shona and ndebele classifier. A further weakness of the library used is it's failure to cater for oximorones or combinations of words which independantly may potray a different sentiment.
#
# #### Recommendations
# It is recommended that a different library which considers combinations of words be used e.g. bigrams for better results. It is also recommended that a shona, ndebele and english classifier be used to split the data into the 3 different lunguages with each dataset analysed separately. Shona and ndebele lunguage dictionaries have to be developed with polarity and objectivity of each word determined to allow sentiment analysis of the shona and ndebele datasets.

# %% [markdown]
# ## *References*

# %% [markdown]
# K. Rudra, S. Ghosh, N. Ganguly, P. Goyal, S. Ghosh, "Extracting situational information from microblogs during disaster events: A classification-summarization approach", Proc. 24th ACM Int. Conf. Inf. Knowl. Manage. (CIKM), pp. 583-592, 2015.
#
# Gao, H., Wang, X., Barbier, G., & Liu, H. (2011b). Promoting coordination for disaster relief: Fromcrowdsourcing to coordination. In J. Salerno, S. J. Yang, D. Nau & S.-K. Chai (Eds.), Socialcomputing, behavioural-cultural modelling, and prediction. Lecture Notes in Computer Science6589 (pp. 197–204). Heidelberg: Springer.
#
# Plotnick, L., White, C., & Plummer, M. (2009). The design of an online social network for emergencymanagement: A one stop shop. In Proceedings of the 15th Americas Conference on InformationSystems, San Francisco, California 6–9 August 2009, pp. 1–9
